# %% [markdown]
# # [Prof. Dalvan Griebler](mailto:dalvan.griebler@pucrs.br)
#
# ## Programação Orientada a Dados (POD) - Turma 10 (POD_98H04-06)
#
# **Atualizado**: 29/10/2021
#
# **Descrição**: Material de apoio as aulas sobre Python para POD
#
# **Copyright &copy;**: Este documento está sob a licensa da Criative Commons [BY-NC-ND 4.0](https://creativecommons.org/licenses/by-nc-nd/4.0/legalcode)

# %% [markdown]
# # Biblioteca Pandas do Python

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Limpeza e Preparação de Dados

# %% [markdown]
# ### Lidando com Dados Ausentes

# %% [markdown]
# ### Filtrando Dados Ausentes

# %% [markdown]
# ### Preenchendo Dados Ausentes

# %% [markdown]
# ## Transformação de Dados

# %% [markdown]
# ### Removendo Dados Duplicados

# %% [markdown]
# ### Transformando Dados com Map

# %% [markdown]
# ### Substituindo Valores

# %% [markdown]
# ### Renomeando Índices de um Eixo

# %% [markdown]
# ### Discretização e Binning (compartimentos)

# %% [markdown]
# ### Detecção de Valores Descrepantes/Outiliers

# %% [markdown]
# ### Permutação e Amostragem Aleatória

# %% [markdown]
# ### DataFrames com Valores Dummy

# %% [markdown]
# ### Manipulação de Strings

# %% [markdown]
# ## Tratamento e Manipulação de Dados

# %% [markdown]
# ### Indexação Hierárquica

# %% [markdown]
# ### Combinação e Mesclagem de dados

# %%
df1 = pd.DataFrame( {'chave': ['a', 'b', 'c', 'd', 'a', 'b'], 
                     'dados': range(6)})

df2 = pd.DataFrame( {'chave': ['a', 'b', 'c'], 
                     'dados': range(3)})


display(df1)
display(df2)

df_m = pd.merge(df1,df2, on='chave')

display(df_m)
# Out:
#   chave  dados
# 0     a      0
# 1     b      1
# 2     c      2
# 3     d      3
# 4     a      4
# 5     b      5
#   chave  dados
# 0     a      0
# 1     b      1
# 2     c      2
#   chave  dados_x  dados_y
# 0     a        0        0
# 1     a        4        0
# 2     b        1        1
# 3     b        5        1
# 4     c        2        2

# %%
df1 = pd.DataFrame( {'chave1': ['a', 'b', 'c', 'd', 'a', 'b'], 
                     'dados': range(1,7)})

df2 = pd.DataFrame( {'chave2': ['a', 'b', 'c'], 
                     'dados': range(1,4)})

display(df1)
display(df2)

df_m = pd.merge(df1,df2, left_on='chave1', right_on='chave2', suffixes=('_esq', '_dir'))

display(df_m)
# Out:
#   chave1  dados
# 0      a      1
# 1      b      2
# 2      c      3
# 3      d      4
# 4      a      5
# 5      b      6
#   chave2  dados
# 0      a      1
# 1      b      2
# 2      c      3
#   chave1  dados_esq chave2  dados_dir
# 0      a          1      a          1
# 1      a          5      a          1
# 2      b          2      b          2
# 3      b          6      b          2
# 4      c          3      c          3

# %%
df1 = pd.DataFrame( {'chave': ['a', 'b', 'c', 'd', 'a', 'b'], 
                     'dados': range(1,7)})

df2 = pd.DataFrame( {'chave': ['a', 'b', 'c'], 
                     'dados': range(1,4)})

display(df1)
display(df2)


df_m = pd.merge(df1,df2)
display(df_m)

df_m = pd.merge(df1,df2, how='outer')
display(df_m)
# Out:
#   chave  dados
# 0     a      1
# 1     b      2
# 2     c      3
# 3     d      4
# 4     a      5
# 5     b      6
#   chave  dados
# 0     a      1
# 1     b      2
# 2     c      3
#   chave  dados
# 0     a      1
# 1     b      2
# 2     c      3
#   chave  dados
# 0     a      1
# 1     b      2
# 2     c      3
# 3     d      4
# 4     a      5
# 5     b      6

# %%
s1 = pd.Series(range(1,3), index=['a', 'b'])
s2 = pd.Series(range(3,6), index=['c', 'd', 'e'])
s3 = pd.Series(range(6,8), index=['f', 'g'])


print(s1)
print(s2)
print(s3)

display(pd.concat([s1, s2, s3]))

display(pd.concat([s1, s2, s3], axis=1))
# Out:
# a    1
# b    2
# dtype: int64
# c    3
# d    4
# e    5
# dtype: int64
# f    6
# g    7
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64
#      0    1    2
# a  1.0  NaN  NaN
# b  2.0  NaN  NaN
# c  NaN  3.0  NaN
# d  NaN  4.0  NaN
# e  NaN  5.0  NaN
# f  NaN  NaN  6.0
# g  NaN  NaN  7.0

# %%
s4 = pd.concat([s1, s3])

print(s1)
print(s4)

display(pd.concat([s1,s4], axis=1, join='outer'))
# Out:
# a    1
# b    2
# dtype: int64
# a    1
# b    2
# f    6
# g    7
# dtype: int64
#      0  1
# a  1.0  1
# b  2.0  2
# f  NaN  6
# g  NaN  7

# %% [markdown]
# ## Reformatação e Pivotamento

# %% [markdown]
# ## Agregação e Operações em Grupo

# %% [markdown]
# ### GroupBy

# %%
df = pd.DataFrame( {'chave1': ['a', 'b', 'c', 'd', 'a'], 
                     'chave2': ['um', 'dois', 'um', 'dois', 'um'],
                     'dados1': np.random.randn(5),
                     'dados2': np.random.randn(5)}                    
                     )

display(df)

G = df['dados1'].groupby(df['chave1'])

print(G.describe())
# Out:
#   chave1 chave2    dados1    dados2
# 0      a     um -0.597786  1.055338
# 1      b   dois -0.929035 -0.265041
# 2      c     um  0.224205 -0.701832
# 3      d   dois  0.094973  0.962521
# 4      a     um -0.634746  0.432727
#         count      mean       std       min       25%       50%       75%  \
# chave1
# a         2.0 -0.616266  0.026134 -0.634746 -0.625506 -0.616266 -0.607026
# b         1.0 -0.929035       NaN -0.929035 -0.929035 -0.929035 -0.929035
# c         1.0  0.224205       NaN  0.224205  0.224205  0.224205  0.224205
# d         1.0  0.094973       NaN  0.094973  0.094973  0.094973  0.094973
#
#              max
# chave1
# a      -0.597786
# b      -0.929035
# c       0.224205
# d       0.094973

# %%
display(df)

G = df.groupby(df.dtypes, axis=1)

print(G.describe())
# Out:
#   chave1 chave2    dados1    dados2
# 0      a     um -0.597786  1.055338
# 1      b   dois -0.929035 -0.265041
# 2      c     um  0.224205 -0.701832
# 3      d   dois  0.094973  0.962521
# 4      a     um -0.634746  0.432727
#        count      mean       std       min       25%       50%       75%  \
# chave1     5       NaN       NaN       NaN       NaN       NaN       NaN
# chave2     5       NaN       NaN       NaN       NaN       NaN       NaN
# dados1   5.0 -0.368478   0.50094 -0.929035 -0.634746 -0.597786  0.094973
# dados2   5.0  0.296742  0.766481 -0.701832 -0.265041  0.432727  0.962521
#
#              max unique  top freq
# chave1       NaN      4    a    2
# chave2       NaN      2   um    3
# dados1  0.224205    NaN  NaN  NaN
# dados2  1.055338    NaN  NaN  NaN

# %% [markdown]
# ### Iteração

# %% [markdown]
# ### Selecionando uma ou subconjunto de colunas

# %% [markdown]
# ### Agrupamento com dicionários e series

# %% [markdown]
# ### Agrupamento com funções

# %% [markdown]
# ### Agrupamento por níveis de indices

# %% [markdown]
# ## Agregação de Dados

# %% [markdown]
# ### Método Apply

# %%
# realize um agrupamento por equipe Mandante para identificar as equipemes
# com o maior número de gols.

def top(df, n=5, Coluna='Mandante Placar'):
    return df.sort_values(by=Coluna)[-n:]


df = pd.read_csv('brasi2000-2021.csv')

display(top(df, n=10))

display(df.groupby('Mandante').apply(top).sort_values(by='Mandante Placar', ascending=False).head(10))
# Out:
#         ID Rodada        Data Horário           Dia      Mandante   Visitante  \
# 1480  1481     36  2003-10-12   16h00       Domingo         Goiás  Fluminense
# 3222  3223     23  2007-09-01   18h10        Sábado     São Paulo      Paraná
# 1122  1123      6  2003-04-27   16h00       Domingo         Goiás   Juventude
# 2557  2558     37  2005-11-06   16h00       Domingo   Corinthians      Santos
# 1671  1672      6  2004-05-16   16h00       Domingo      Criciúma       Goiás
# 357    358      2  2001-08-05   14h30       Domingo         Vasco     Guarani
# 2309  2310     15  2005-07-27   21h45  Quarta-feira  Athlético-PR       Vasco
# 2055  2056     38  2004-10-27   20h30  Quarta-feira    Fluminense   Juventude
# 1992  1993     33  2004-09-28   20h30   Terça-feira     São Paulo    Paysandu
# 693    694     26  2001-11-25   16h00       Domingo         Vasco   São Paulo
#
#           Vencedor                Arena  Mandante Placar  Visitante Placar  \
# 1480         Goiás        Serra Dourada                6                 1
# 3222     São Paulo              Morumbi                6                 0
# 1122         Goiás        Serra Dourada                7                 0
# 2557   Corinthians             Pacaembu                7                 1
# 1671      Criciúma      Heriberto Hulse                7                 2
# 357          Vasco         São Januário                7                 1
# 2309  Athlético-PR     Arena da Baixada                7                 2
# 2055    Fluminense  Raulino de Oliveira                7                 1
# 1992     São Paulo              Morumbi                7                 0
# 693          Vasco         São Januário                7                 1
#
#      Estado Mandante Estado Visitante Estado Vencedor
# 1480              GO               RJ              GO
# 3222              SP               PR              SP
# 1122              GO               RS              GO
# 2557              SP               SP              SP
# 1671              SC               GO              SC
# 357               RJ               SP              RJ
# 2309              PR               RJ              PR
# 2055              RJ               RS              RJ
# 1992              SP               PA              SP
# 693               RJ               SP              RJ
#                      ID Rodada        Data Horário           Dia  \
# Mandante
# Corinthians  2557  2558     37  2005-11-06   16h00       Domingo
# Criciúma     1671  1672      6  2004-05-16   16h00       Domingo
# Goiás        1122  1123      6  2003-04-27   16h00       Domingo
# Vasco        693    694     26  2001-11-25   16h00       Domingo
#              357    358      2  2001-08-05   14h30       Domingo
# São Paulo    1992  1993     33  2004-09-28   20h30   Terça-feira
# Athlético-PR 2309  2310     15  2005-07-27   21h45  Quarta-feira
# Fluminense   2055  2056     38  2004-10-27   20h30  Quarta-feira
# Goiás        5884  5885     23  2014-09-21   18h30       Domingo
# Fluminense   232    233     27  2000-10-25   20h30  Quarta-feira
#
#                        Mandante   Visitante      Vencedor  \
# Mandante
# Corinthians  2557   Corinthians      Santos   Corinthians
# Criciúma     1671      Criciúma       Goiás      Criciúma
# Goiás        1122         Goiás   Juventude         Goiás
# Vasco        693          Vasco   São Paulo         Vasco
#              357          Vasco     Guarani         Vasco
# São Paulo    1992     São Paulo    Paysandu     São Paulo
# Athlético-PR 2309  Athlético-PR       Vasco  Athlético-PR
# Fluminense   2055    Fluminense   Juventude    Fluminense
# Goiás        5884         Goiás   Palmeiras         Goiás
# Fluminense   232     Fluminense  Santa Cruz    Fluminense
#
#                                  Arena  Mandante Placar  Visitante Placar  \
# Mandante
# Corinthians  2557             Pacaembu                7                 1
# Criciúma     1671      Heriberto Hulse                7                 2
# Goiás        1122        Serra Dourada                7                 0
# Vasco        693          São Januário                7                 1
#              357          São Januário                7                 1
# São Paulo    1992              Morumbi                7                 0
# Athlético-PR 2309     Arena da Baixada                7                 2
# Fluminense   2055  Raulino de Oliveira                7                 1
# Goiás        5884        Serra Dourada                6                 0
# Fluminense   232              Maracanã                6                 1
#
#                   Estado Mandante Estado Visitante Estado Vencedor
# Mandante
# Corinthians  2557              SP               SP              SP
# Criciúma     1671              SC               GO              SC
# Goiás        1122              GO               RS              GO
# Vasco        693               RJ               SP              RJ
#              357               RJ               SP              RJ
# São Paulo    1992              SP               PA              SP
# Athlético-PR 2309              PR               RJ              PR
# Fluminense   2055              RJ               RS              RJ
# Goiás        5884              GO               SP              GO
# Fluminense   232               RJ               PE              RJ

# %% [markdown]
# ### Pivot e Cross Table com Agregação
