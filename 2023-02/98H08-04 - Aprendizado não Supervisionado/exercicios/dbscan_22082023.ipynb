# %%
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.cluster import DBSCAN
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
data = pd.read_csv('./Live.csv', index_col='status_id')
data
# Out:
#                                   status_type status_published  num_reactions
# status_id
# 246675545449582_1649696485147474        video   4/22/2018 6:00            529  \
# 246675545449582_1649426988507757        photo  4/21/2018 22:45            150
# 246675545449582_1648730588577397        video   4/21/2018 6:17            227
# 246675545449582_1648576705259452        photo   4/21/2018 2:29            111
# 246675545449582_1645700502213739        photo   4/18/2018 3:22            213
# ...                                       ...              ...            ...
# 1050855161656896_1061863470556065       photo   9/24/2016 2:58             89
# 1050855161656896_1061334757275603       photo  9/23/2016 11:19             16
# 1050855161656896_1060126464063099       photo  9/21/2016 23:03              2
# 1050855161656896_1058663487542730       photo   9/20/2016 0:43            351
# 1050855161656896_1050858841656528       photo  9/10/2016 10:30             17
#
# ...

# %%
categorical_features = ['status_type']
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)])

dbscan = DBSCAN(eps=0.1, min_samples=5)

clf = Pipeline(steps=[('preprocessor', preprocessor), ('cluster', dbscan)])

# %%
data = data.reset_index()[['status_type', 'num_reactions', 'num_comments',
       'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hahas',
       'num_sads', 'num_angrys']]

clf.fit(data)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['status_type'])])),
#                 ('cluster', DBSCAN(eps=0.1))])

# %%
pd.unique(clf[1].labels_)
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
#plot classification result
plt.scatter(data['num_reactions'], data['num_comments'], c=clf[1].labels_, cmap='rainbow')
plt.show()
