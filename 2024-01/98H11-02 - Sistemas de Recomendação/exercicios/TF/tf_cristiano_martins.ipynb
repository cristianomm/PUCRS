# %%
import warnings, requests
import pandas as pd
import numpy as np
import empyrical as ep
import plotly.express as plt

from datetime import datetime

warnings.filterwarnings('ignore')

# %%
class Tools:
    def __init__(self):
        self.path = 'D:/Disco/Data/CVM'

    def compute_metrics(self, fund_cnpj, funds_series, length):
        fund_data = funds_series[funds_series['CNPJ_FUNDO'] == fund_cnpj][['DT_COMPTC', 'VL_QUOTA']].tail(length)
        fund_data = fund_data.rename(columns={'DT_COMPTC':'date', 'VL_QUOTA':'value'})
        fund_data.drop_duplicates(keep='last', inplace=True)
        fund_data.set_index('date', inplace=True)

        fund_data['returns'] = ep.simple_returns(fund_data['value'])
        fund_data['returns'] = fund_data['returns'].replace([np.inf, -np.inf], np.nan)
        fund_data = fund_data.dropna()

        #selic['returns'] = ep.simple_returns(selic['value'])
        #selic_temp = selic[selic.index.isin(fund_data.index.values)]

        data = {
            'cnpj':fund_cnpj,
            'return': (1 + fund_data['returns']).cumprod()[-1] -1, 
            'avg_return': ep.annual_return(fund_data['returns']),
            'vol': np.std(fund_data['returns']) * np.sqrt(252),
            'max_dd': ep.max_drawdown(fund_data['returns'])
            #'sharpe': ep.sharpe_ratio(fund_data['returns'], ep.annual_return(selic_temp['returns']))
        }

        return pd.DataFrame([data])

    def getBCBSerie(self, serie_id, serie_name):
        data = requests.get(f"https://api.bcb.gov.br/dados/serie/bcdata.sgs.{serie_id} \
                            /dados?dataInicial=01-01-1970 \
                            &dataFinal={datetime.today().strftime('%d-%m-%Y')}").json()

        data = pd.DataFrame(data, dtype=float, columns=['data', 'valor']).rename(columns={'data':'date', 'valor':'value'})
        data.set_index('date', inplace=True)
        data['index_id'] = serie_id
        data['index_name'] = serie_name
        data.index = pd.to_datetime(data.index, format="%d/%m/%Y")
        
        return data
    
    def computeReturn(self, data, start_date, end_date):
        returns = data.loc[(data.index >= start_date) & (data.index <= end_date)]
        if(len(returns)>0):
            returns['value'] = (1 + returns['value'] / 100)
            returns.loc[returns.index.min()]['value'] = 1
            returns['value'] = (returns['value']).cumprod()
            returns['value'] = (returns['value'] - 1)
        else:
            returns = pd.DataFrame(pd.date_range(start_date, end_date), columns={'date'}).set_index('date')
            returns['value'] = 0

        return returns

    def loadCVMData():
        pass

# %%
tools = Tools()

# %%
selic = tools.getBCBSerie(11, 'SELIC')

# %%
selic.tail(5)

# %%
inf_cadastral = pd.read_parquet(f'{tools.path}/inf_cadastral.parquet')
inf_cadastral = inf_cadastral[(inf_cadastral['FUNDO_EXCLUSIVO'] == "N") & (inf_cadastral['SIT'] == "EM FUNCIONAMENTO NORMAL")]
inf_cadastral.index = inf_cadastral.index.str.replace('.','').str.replace('/', '').str.replace('-', '')
print(len(inf_cadastral))

inf_cadastral.head(3)

# %%
inf_diario = pd.read_parquet(f'{tools.path}/inf_diario_all.parquet').reset_index()
print(len(inf_diario))

#filtra as series conforme os cnpj validos
inf_diario = inf_diario[inf_diario['CNPJ_FUNDO'].isin(inf_cadastral.index.values)]
inf_diario['DT_COMPTC'] = pd.to_datetime(inf_diario['DT_COMPTC'], format='%Y-%m-%d')
print(len(inf_diario))

inf_diario.head(5)

# %%
funds_series = pd.merge(inf_cadastral[['TP_FUNDO', 'DENOM_SOCIAL', 'CLASSE_ANBIMA', 'CLASSE', 'RENTAB_FUNDO', 'PUBLICO_ALVO']], 
         inf_diario[['DT_COMPTC', 'CNPJ_FUNDO', 'VL_TOTAL', 'VL_QUOTA', 'VL_PATRIM_LIQ']], 
         how='inner',left_on='CNPJ_FUNDO', right_on='CNPJ_FUNDO')

del inf_cadastral, inf_diario

#salva em arquivo os dados
funds_series.to_parquet(f'{tools.path}/funds_series.parquet')

# %%
funds_series = pd.read_parquet(f'{tools.path}/funds_series.parquet')

# %%
funds_series.head(4)

# %%
#00068305000135

fund_data = funds_series[funds_series['CNPJ_FUNDO'] == '30271177000193'][['DT_COMPTC', 'VL_QUOTA']]
fund_data = fund_data.rename(columns={'DT_COMPTC':'date', 'VL_QUOTA':'value'})
fund_data.set_index('date', inplace=True)


selic_temp = selic[selic.index.isin(fund_data.index.values)]

# %%
plt.line(fund_data)

# %%
fund_data['returns'] = ep.simple_returns(fund_data['value'])
fund_data['returns'].replace([np.inf, -np.inf], np.nan)
fund_data = fund_data.dropna(subset=['returns'])

selic['returns'] = ep.simple_returns(selic['value'])

selic_temp = selic[selic.index.isin(fund_data.index.values)]

# %%
plt.line(fund_data['returns'])

# %%
plt.line(selic_temp['returns'])

# %%
serie_size = 1260
funds_metrics = pd.DataFrame()

count=0
for cnpj in funds_series['CNPJ_FUNDO'].unique():
    serie = funds_series[funds_series['CNPJ_FUNDO'] == cnpj]
    
    if len(serie) > serie_size:
        print(f'computing metrics for: {cnpj}')
        metrics = tools.compute_metrics(cnpj, serie, serie_size)
        funds_metrics = pd.concat([funds_metrics, metrics])
        count +=1
        if count > 20:
            print('saving file...')
            count = 0
            funds_metrics.to_parquet('./funds_metrics.parquet')

funds_metrics.reset_index(inplace=True)
funds_metrics.to_parquet('./funds_metrics.parquet')
# Out:
# computing metrics for: 00068305000135
# computing metrics for: 00071477000168
# computing metrics for: 00073041000108
# computing metrics for: 00083181000167
# computing metrics for: 00089915000115
# computing metrics for: 00102322000141
# computing metrics for: 00180995000110
# computing metrics for: 00185259000154
# computing metrics for: 00194256000187
# computing metrics for: 00211294000109
# computing metrics for: 00222725000124
# computing metrics for: 00222816000160
# computing metrics for: 00280302000160
# computing metrics for: 00306278000191
# computing metrics for: 00322699000106
# computing metrics for: 00346750000110
# computing metrics for: 00360293000118
# computing metrics for: 00398561000190
# computing metrics for: 00400490000113
# computing metrics for: 00463569000193
# computing metrics for: 00524617000106
# saving file...
# computing metrics for: 00539553000117
# computing metrics for: 00575922000127
# computing metrics for: 00598452000117
# computing metrics for: 00601692000123
# computing metrics for: 00743026000120
# computing metrics for: 00756851000169
# computing metrics for: 00777815000181
# computing metrics for: 00785365000179
# computing metrics for: 00793947000105
# computing metrics for: 00807777000162
# computing metrics for: 00809773000113
# computing metrics for: 00812433000141
# computing metrics for: 00813342000120
# computing metrics for: 00817201000186
# computing metrics for: 00817677000117
# computing metrics for: 00819858000182
# computing metrics for: 00819875000110
# computing metrics for: 00819880000122
# computing metrics for: 00819889000133
# computing metrics for: 00819901000100
# computing metrics for: 01562582000162
# computing metrics for: 01578474000188
# computing metrics for: 01587403000141
# saving file...
# computing metrics for: 01590019000106
# computing metrics for: 01591605000167
# computing metrics for: 01597187000115
# computing metrics for: 01597275000117
# computing metrics for: 01599628000118
# computing metrics for: 01603578000103
# computing metrics for: 01605280000124
# computing metrics for: 01606543000110
# computing metrics for: 01606544000164
# computing metrics for: 01606545000109
# computing metrics for: 01606546000153
# computing metrics for: 01606552000100
# computing metrics for: 01608399000150
# computing metrics for: 01608572000110
# computing metrics for: 01608573000165
# computing metrics for: 01613104000134
# computing metrics for: 01615744000183
# computing metrics for: 01620027000140
# computing metrics for: 01620606000192
# computing metrics for: 01623379000159
# computing metrics for: 01623389000194
# saving file...
# computing metrics for: 01623535000181
# computing metrics for: 01623538000115
# computing metrics for: 01623857000120
# computing metrics for: 01624111000131
# computing metrics for: 01624178000176
# computing metrics for: 01624316000117
# computing metrics for: 01625681000146
# computing metrics for: 01625682000190
# computing metrics for: 01626956000166
# computing metrics for: 01626961000179
# computing metrics for: 01627516000123
# computing metrics for: 01630152000130
# computing metrics for: 01630558000113
# computing metrics for: 01631246000124
# computing metrics for: 01634642000105
# computing metrics for: 01643271000128
# computing metrics for: 01655956000194
# computing metrics for: 01656101000188
# computing metrics for: 01675497000100
# computing metrics for: 01678491000197
# computing metrics for: 01699688000102
# saving file...
# computing metrics for: 01745808000160
# computing metrics for: 01753087000130
# computing metrics for: 01757217000103
# computing metrics for: 01776200000101
# computing metrics for: 01789400000190
# computing metrics for: 01822655000108
# computing metrics for: 01823373000125
# computing metrics for: 01889170000131
# computing metrics for: 01960341000171
# computing metrics for: 01972663000130
# computing metrics for: 01975502000109
# computing metrics for: 01978445000103
# computing metrics for: 01996007000178
# computing metrics for: 02010147000198
# computing metrics for: 02020528000158
# computing metrics for: 02037763000132
# computing metrics for: 02081341000164
# computing metrics for: 02097249000192
# computing metrics for: 02097252000106
# computing metrics for: 02097253000150
# computing metrics for: 02127428000125
# saving file...
# computing metrics for: 02131724000108
# computing metrics for: 02131725000144
# computing metrics for: 02138442000124
# computing metrics for: 02162620000152
# computing metrics for: 02171479000154
# computing metrics for: 02198411000169
# computing metrics for: 02201163000168
# computing metrics for: 02201164000102
# computing metrics for: 02201500000117
# computing metrics for: 02205515000153
# computing metrics for: 02222178000102
# computing metrics for: 02224354000145
# computing metrics for: 02224382000162
# computing metrics for: 02266145000164
# computing metrics for: 02290048000107
# computing metrics for: 02290279000110
# computing metrics for: 02290305000100
# computing metrics for: 02294024000126
# computing metrics for: 02294026000115
# computing metrics for: 02294033000117
# computing metrics for: 02296928000190
# saving file...
# computing metrics for: 02297087000136
# computing metrics for: 02323746000161
# computing metrics for: 02335944000145
# computing metrics for: 02343288000122
# computing metrics for: 02367527000184
# computing metrics for: 02430487000178
# computing metrics for: 02436763000105
# computing metrics for: 02444266000159
# computing metrics for: 02480563000150
# computing metrics for: 02497034000169
# computing metrics for: 02498096000195
# computing metrics for: 02498189000110
# computing metrics for: 02498190000144
# computing metrics for: 02498201000196
# computing metrics for: 02498204000120
# computing metrics for: 02498604000135
# computing metrics for: 04178681000133
# computing metrics for: 04187008000160
# computing metrics for: 04192419000143
# computing metrics for: 04194710000150
# computing metrics for: 04195359000112
# computing metrics for: 04200930000140
# computing metrics for: 04201010000146
# computing metrics for: 04215425000179
# computing metrics for: 04220338000100
# computing metrics for: 04222368000155
# saving file...
# computing metrics for: 04222376000100
# computing metrics for: 04222383000101
# computing metrics for: 04222426000140
# computing metrics for: 04222433000142
# computing metrics for: 04222437000120
# computing metrics for: 04222716000194
# computing metrics for: 04228545000100
# computing metrics for: 04237569000126
# computing metrics for: 04237578000117
# computing metrics for: 04237583000120
# computing metrics for: 04240128000183
# computing metrics for: 04244137000142
# computing metrics for: 04244149000177
# computing metrics for: 04253072000100
# computing metrics for: 04253078000179
# computing metrics for: 04260468000176
# computing metrics for: 04260579000182
# computing metrics for: 04262710000140
# computing metrics for: 04272487000112
# computing metrics for: 04277486000160
# computing metrics for: 04277488000150
# saving file...
# computing metrics for: 04277491000173
# computing metrics for: 04288780000178
# computing metrics for: 04288830000117
# computing metrics for: 04288944000167
# computing metrics for: 04288966000127
# computing metrics for: 04289051000136
# computing metrics for: 04299355000184
# computing metrics for: 04299586000198
# computing metrics for: 04299610000199
# computing metrics for: 04299727000172
# computing metrics for: 04305193000140
# computing metrics for: 04310455000164
# computing metrics for: 04311271000119
# computing metrics for: 04320223000197
# computing metrics for: 04320863000105
# computing metrics for: 04328542000149
# computing metrics for: 04331424000190
# computing metrics for: 04335156000184
# computing metrics for: 04335567000170
# computing metrics for: 04337571000177
# computing metrics for: 04342594000170
# saving file...
# computing metrics for: 04342618000190
# computing metrics for: 04345323000178
# computing metrics for: 04348384000199
# computing metrics for: 04350787000172
# computing metrics for: 04353257000188
# computing metrics for: 04380741000104
# computing metrics for: 04385278000185
# computing metrics for: 04412762000156
# computing metrics for: 04418494000180
# computing metrics for: 04418568000188
# computing metrics for: 04418668000104
# computing metrics for: 04426895000181
# computing metrics for: 04435076000109
# computing metrics for: 04437399000123
# computing metrics for: 04437609000183
# computing metrics for: 04437639000190
# computing metrics for: 04440887000190
# computing metrics for: 04443397000147
# computing metrics for: 04443415000190
# computing metrics for: 04443440000174
# computing metrics for: 04443459000110
# saving file...
# computing metrics for: 04445295000160
# computing metrics for: 04451473000166
# computing metrics for: 04455632000109
# computing metrics for: 04455642000136
# computing metrics for: 04495282000104
# computing metrics for: 04497742000125
# computing metrics for: 04501865000192
# computing metrics for: 04510683000188
# computing metrics for: 04511286000120
# computing metrics for: 04514122000157
# computing metrics for: 04516930000153
# computing metrics for: 04519681000150
# computing metrics for: 04519722000108
# computing metrics for: 04520220000105
# computing metrics for: 04521982000118
# computing metrics for: 04523214000101
# computing metrics for: 04525916000116
# computing metrics for: 04528776000130
# computing metrics for: 04530186000141
# computing metrics for: 04539345000179
# computing metrics for: 04553189000109
# saving file...
# computing metrics for: 04554221000162
# computing metrics for: 04566470000178
# computing metrics for: 04568060000166
# computing metrics for: 04570232000136
# computing metrics for: 04572903000106
# computing metrics for: 04573104000146
# computing metrics for: 04573108000124
# computing metrics for: 04573842000193
# computing metrics for: 04573850000130
# computing metrics for: 04579712000168
# computing metrics for: 04588017000162
# computing metrics for: 04588071000108
# computing metrics for: 04589359000105
# computing metrics for: 04589378000123
# computing metrics for: 04589516000174
# computing metrics for: 04592305000190
# computing metrics for: 04602186000100
# computing metrics for: 04609196000177
# computing metrics for: 04609212000121
# computing metrics for: 04616277000102
# computing metrics for: 04616299000164
# saving file...
# computing metrics for: 04621018000161
# computing metrics for: 04621721000170
# computing metrics for: 04644580000100
# computing metrics for: 04652510000102
# computing metrics for: 04662147000106
# computing metrics for: 04662450000109
# computing metrics for: 04667988000106
# computing metrics for: 04679647000142
# computing metrics for: 04682022000130
# computing metrics for: 04682496000181
# computing metrics for: 04682806000168
# computing metrics for: 04684251000193
# computing metrics for: 04684453000135
# computing metrics for: 04684467000159
# computing metrics for: 04684472000161
# computing metrics for: 04684491000198
# computing metrics for: 04684499000154
# computing metrics for: 04684515000109
# computing metrics for: 04687535000133
# computing metrics for: 04699653000161
# computing metrics for: 04699738000140
# saving file...
# computing metrics for: 04700116000194
# computing metrics for: 04700335000173
# computing metrics for: 04700351000166
# computing metrics for: 04700366000124
# computing metrics for: 04701028000107
# computing metrics for: 04701088000120
# computing metrics for: 04701133000146
# computing metrics for: 04701240000174
# computing metrics for: 04702079000153
# computing metrics for: 04702944000161
# computing metrics for: 04703001000153
# computing metrics for: 04703087000114
# computing metrics for: 04703103000179
# computing metrics for: 04714699000102
# computing metrics for: 04715360000120
# computing metrics for: 04733518000195
# computing metrics for: 04736006000182
# computing metrics for: 04751820000176
# computing metrics for: 04755506000161
# computing metrics for: 04764174000181
# computing metrics for: 04773506000194
# saving file...
# computing metrics for: 04781328000143
# computing metrics for: 04782012000176
# computing metrics for: 04786966000157
# computing metrics for: 04786973000159
# computing metrics for: 04787992000108
# computing metrics for: 04794886000143
# computing metrics for: 04804980000136
# computing metrics for: 04804991000116
# computing metrics for: 04806420000110
# computing metrics for: 04812385000142
# computing metrics for: 04816776000135
# computing metrics for: 04817198000151
# computing metrics for: 04820026000137
# computing metrics for: 04822511000140
# computing metrics for: 04822739000130
# computing metrics for: 04823412000182
# computing metrics for: 04828795000181
# computing metrics for: 04830277000100
# computing metrics for: 04830474000111
# computing metrics for: 04830483000102
# computing metrics for: 04831907000153
# saving file...
# computing metrics for: 04836724000120
# computing metrics for: 04839017000198
# computing metrics for: 04839917000135
# computing metrics for: 04839930000194
# computing metrics for: 04841651000165
# computing metrics for: 04841657000132
# computing metrics for: 04841745000134
# computing metrics for: 04848106000109
# computing metrics for: 04857834000179
# computing metrics for: 04866784000196
# computing metrics for: 04869180000101
# computing metrics for: 04871634000170
# computing metrics for: 04871688000136
# computing metrics for: 04871799000142
# computing metrics for: 04871830000145
# computing metrics for: 04874802000181
# computing metrics for: 04874817000140
# computing metrics for: 04875006000163
# computing metrics for: 04875086000157
# computing metrics for: 04875166000102
# computing metrics for: 04881158000179
# saving file...
# computing metrics for: 04881177000103
# computing metrics for: 04881191000107
# computing metrics for: 04881197000176
# computing metrics for: 04881676000192
# computing metrics for: 04881682000140
# computing metrics for: 04881687000172
# computing metrics for: 04882596000151
# computing metrics for: 04882611000161
# computing metrics for: 04882617000139
# computing metrics for: 04882637000100
# computing metrics for: 04882647000145
# computing metrics for: 04882688000131
# computing metrics for: 04884545000169
# computing metrics for: 04884567000129
# computing metrics for: 04885403000116
# computing metrics for: 04885571000101
# computing metrics for: 04885601000180
# computing metrics for: 04885818000190
# computing metrics for: 04885820000169
# computing metrics for: 04885824000147
# computing metrics for: 04885832000193
# saving file...
# computing metrics for: 04887951000185
# computing metrics for: 04887966000143
# computing metrics for: 04887978000178
# computing metrics for: 04887986000114
# computing metrics for: 04889781000178
# computing metrics for: 04889791000103
# computing metrics for: 04889824000115
# computing metrics for: 04890401000115
# computing metrics for: 04891399000107
# computing metrics for: 04892107000142
# computing metrics for: 04892365000129
# computing metrics for: 04892367000118
# computing metrics for: 04892370000131
# computing metrics for: 04894403000182
# computing metrics for: 04894410000184
# computing metrics for: 04894428000186
# computing metrics for: 04894780000111
# computing metrics for: 04895099000198
# computing metrics for: 04895190000103
# computing metrics for: 04895210000146
# computing metrics for: 04895277000180
# saving file...
# computing metrics for: 04896996000116
# computing metrics for: 04897604000133
# computing metrics for: 04899128000190
# computing metrics for: 04899165000106
# computing metrics for: 04899182000135
# computing metrics for: 04906948000161
# computing metrics for: 04912431000185
# computing metrics for: 04912456000189
# computing metrics for: 04934288000122
# computing metrics for: 04934293000135
# computing metrics for: 04934357000106
# computing metrics for: 04957589000171
# computing metrics for: 04965504000105
# computing metrics for: 04968651000120
# computing metrics for: 05006152000115
# computing metrics for: 05011902000147
# computing metrics for: 05018037000160
# computing metrics for: 05023746000134
# computing metrics for: 05024659000100
# computing metrics for: 05024715000106
# computing metrics for: 05024910000128
# saving file...
# computing metrics for: 05024919000139
# computing metrics for: 05025886000141
# computing metrics for: 05025900000107
# computing metrics for: 05032585000145
# computing metrics for: 05043209000156
# computing metrics for: 05044708000168
# computing metrics for: 05044718000101
# computing metrics for: 05053850000171
# computing metrics for: 05063643000106
# computing metrics for: 05069379000100
# computing metrics for: 05073650000180
# computing metrics for: 05073656000158
# computing metrics for: 05073662000105
# computing metrics for: 05073744000150
# computing metrics for: 05075861000152
# computing metrics for: 05080623000135
# computing metrics for: 05084425000140
# computing metrics for: 05084445000110
# computing metrics for: 05085727000132
# computing metrics for: 05086234000117
# computing metrics for: 05090705000160
# saving file...
# computing metrics for: 05090727000120
# computing metrics for: 05090740000180
# computing metrics for: 05090753000159
# computing metrics for: 05090757000137
# computing metrics for: 05090763000194
# computing metrics for: 05090771000130
# computing metrics for: 05090778000152
# computing metrics for: 05090786000107
# computing metrics for: 05090817000111
# computing metrics for: 05090830000170
# computing metrics for: 05090867000107
# computing metrics for: 05090896000160
# computing metrics for: 05090913000160
# computing metrics for: 05090920000161
# computing metrics for: 05090962000100
# computing metrics for: 05091139000101
# computing metrics for: 05091439000190
# computing metrics for: 05092223000140
# computing metrics for: 05092264000136
# computing metrics for: 05092294000142
# computing metrics for: 05092810000139
# saving file...
# computing metrics for: 05093013000176
# computing metrics for: 05093031000158
# computing metrics for: 05097427000173
# computing metrics for: 05100191000187
# computing metrics for: 05100213000109
# computing metrics for: 05100221000155
# computing metrics for: 05100230000146
# computing metrics for: 05100234000124
# computing metrics for: 05101760000109
# computing metrics for: 05102500000158
# computing metrics for: 05104184000153
# computing metrics for: 05104498000156
# computing metrics for: 05108305000135
# computing metrics for: 05108368000191
# computing metrics for: 05108379000171
# computing metrics for: 05108398000106
# computing metrics for: 05108403000172
# computing metrics for: 05109839000186
# computing metrics for: 05112439000120
# computing metrics for: 05113533000101
# computing metrics for: 05114711000100
# saving file...
# computing metrics for: 05114716000133
# computing metrics for: 05114733000170
# computing metrics for: 05130389000103
# computing metrics for: 05132901000150
# computing metrics for: 05142777000104
# computing metrics for: 05149221000140
# computing metrics for: 05158545000144
# computing metrics for: 05159292000123
# computing metrics for: 05164317000187
# computing metrics for: 05164325000123
# computing metrics for: 05164353000140
# computing metrics for: 05164356000184
# computing metrics for: 05164358000173
# computing metrics for: 05164361000197
# computing metrics for: 05164362000131
# computing metrics for: 05164364000120
# computing metrics for: 05164366000110
# computing metrics for: 05164368000109
# computing metrics for: 05164370000188
# computing metrics for: 05164375000100
# computing metrics for: 05164377000108
# saving file...
# computing metrics for: 05194812000139
# computing metrics for: 05194813000183
# computing metrics for: 05196208000141
# computing metrics for: 05201532000100
# computing metrics for: 05207090000100
# computing metrics for: 05211523000109
# computing metrics for: 05212008000135
# computing metrics for: 05217490000104
# computing metrics for: 05222507000103
# computing metrics for: 05222509000100
# computing metrics for: 05222510000127
# computing metrics for: 05222533000131
# computing metrics for: 05222536000175
# computing metrics for: 05222538000164
# computing metrics for: 05222545000166
# computing metrics for: 05222547000155
# computing metrics for: 05222550000179
# computing metrics for: 05231562000160
# computing metrics for: 05231651000106
# computing metrics for: 05231760000123
# computing metrics for: 05231773000100
# saving file...
# computing metrics for: 05274252000122
# computing metrics for: 05289237000158
# computing metrics for: 05290139000130
# computing metrics for: 05307874000100
# computing metrics for: 05317156000114
# computing metrics for: 05317159000158
# computing metrics for: 05322696000196
# computing metrics for: 05324449000129
# computing metrics for: 05324555000102
# computing metrics for: 05346352000117
# computing metrics for: 05357507000110
# computing metrics for: 05362670000171
# computing metrics for: 05362674000150
# computing metrics for: 05369195000165
# computing metrics for: 05380745000147
# computing metrics for: 05381676000196
# computing metrics for: 05381809000124
# computing metrics for: 05382556000103
# computing metrics for: 05384841000163
# computing metrics for: 05388033000174
# computing metrics for: 05392300000187
# saving file...
# computing metrics for: 05392310000112
# computing metrics for: 05395859000160
# computing metrics for: 05395936000182
# computing metrics for: 05396695000196
# computing metrics for: 05396707000182
# computing metrics for: 05401257000179
# computing metrics for: 05401962000176
# computing metrics for: 05406585000168
# computing metrics for: 05420135000120
# computing metrics for: 05426951000140
# computing metrics for: 05448587000110
# computing metrics for: 05458523000108
# computing metrics for: 05458600000111
# computing metrics for: 05458910000136
# computing metrics for: 05458928000138
# computing metrics for: 05461721000112
# computing metrics for: 05464910000149
# computing metrics for: 05480352000105
# computing metrics for: 05480353000150
# computing metrics for: 05482325000171
# computing metrics for: 05488919000190
# saving file...
# computing metrics for: 05491225000101
# computing metrics for: 05491230000114
# computing metrics for: 05491551000119
# computing metrics for: 05495393000175
# computing metrics for: 05497231000176
# computing metrics for: 05503706000190
# computing metrics for: 05508422000196
# computing metrics for: 05508427000119
# computing metrics for: 05508431000187
# computing metrics for: 05508504000130
# computing metrics for: 05508529000134
# computing metrics for: 05508550000130
# computing metrics for: 05510759000138
# computing metrics for: 05513181000173
# computing metrics for: 05513229000143
# computing metrics for: 05513332000193
# computing metrics for: 05523348000187
# computing metrics for: 05524130000147
# computing metrics for: 05549144000115
# computing metrics for: 05554339000153
# computing metrics for: 05563613000150
# saving file...
# computing metrics for: 05575327000105
# computing metrics for: 05575445000113
# computing metrics for: 05575465000194
# computing metrics for: 05575480000132
# computing metrics for: 05583449000143
# computing metrics for: 05584030000106
# computing metrics for: 05584551000163
# computing metrics for: 05584616000170
# computing metrics for: 05586694000104
# computing metrics for: 05586704000101
# computing metrics for: 05586710000169
# computing metrics for: 05589418000108
# computing metrics for: 05589424000157
# computing metrics for: 05589433000148
# computing metrics for: 05590804000101
# computing metrics for: 05591837000176
# computing metrics for: 05592150000155
# computing metrics for: 05595259000146
# computing metrics for: 05595398000170
# computing metrics for: 05605879000119
# computing metrics for: 05615511000131
# saving file...
# computing metrics for: 05615522000111
# computing metrics for: 05615541000148
# computing metrics for: 05615621000101
# computing metrics for: 05624592000136
# computing metrics for: 05627929000169
# computing metrics for: 05628772000196
# computing metrics for: 05628792000167
# computing metrics for: 05629454000140
# computing metrics for: 05629872000137
# computing metrics for: 05629888000140
# computing metrics for: 05629893000152
# computing metrics for: 05629904000102
# computing metrics for: 05629940000168
# computing metrics for: 05631933000109
# computing metrics for: 05635774000102
# computing metrics for: 05636365000120
# computing metrics for: 05642617000124
# computing metrics for: 05645156000143
# computing metrics for: 05656536000183
# computing metrics for: 05681154000100
# computing metrics for: 05694242000146
# saving file...
# computing metrics for: 05697562000150
# computing metrics for: 05701082000115
# computing metrics for: 05701758000170
# computing metrics for: 05753141000107
# computing metrics for: 05753821000112
# computing metrics for: 05754026000149
# computing metrics for: 05754033000140
# computing metrics for: 05754041000197
# computing metrics for: 05754046000110
# computing metrics for: 05754066000190
# computing metrics for: 05754101000171
# computing metrics for: 05755769000133
# computing metrics for: 05756488000103
# computing metrics for: 05762725000130
# computing metrics for: 05764779000135
# computing metrics for: 05766862000143
# computing metrics for: 05775723000186
# computing metrics for: 05775731000122
# computing metrics for: 05775774000108
# computing metrics for: 05778214000107
# computing metrics for: 05785045000132
# saving file...
# computing metrics for: 05785188000144
# computing metrics for: 05785303000180
# computing metrics for: 05786899000133
# computing metrics for: 05786931000180
# computing metrics for: 05786938000100
# computing metrics for: 05786944000150
# computing metrics for: 05808851000189
# computing metrics for: 05832360000173
# computing metrics for: 05851880000123
# computing metrics for: 05855398000161
# computing metrics for: 05857973000165
# computing metrics for: 05862817000192
# computing metrics for: 05862906000139
# computing metrics for: 05871539000130
# computing metrics for: 05872456000165
# computing metrics for: 05878458000161
# computing metrics for: 05892509000100
# computing metrics for: 05892516000101
# computing metrics for: 05892566000199
# computing metrics for: 05898357000152
# computing metrics for: 05898535000145
# saving file...
# computing metrics for: 05900798000141
# computing metrics for: 05902468000195
# computing metrics for: 05902490000135
# computing metrics for: 05902493000179
# computing metrics for: 05902521000158
# computing metrics for: 05903152000118
# computing metrics for: 05903160000164
# computing metrics for: 05906026000117
# computing metrics for: 05906033000119
# computing metrics for: 05910030000159
# computing metrics for: 05911520000170
# computing metrics for: 05922462000180
# computing metrics for: 05923901000179
# computing metrics for: 05925923000178
# computing metrics for: 05926162000179
# computing metrics for: 05931528000106
# computing metrics for: 05936210000100
# computing metrics for: 05936530000160
# computing metrics for: 05941167000170
# computing metrics for: 05941170000194
# computing metrics for: 05943661000174
# saving file...
# computing metrics for: 05949051000188
# computing metrics for: 05951508000199
# computing metrics for: 05959219000136
# computing metrics for: 05962491000175
# computing metrics for: 05964067000160
# computing metrics for: 05969595000101
# computing metrics for: 05971745000111
# computing metrics for: 05971921000115
# computing metrics for: 05983545000189
# computing metrics for: 05983558000158
# computing metrics for: 05983569000138
# computing metrics for: 05983641000127
# computing metrics for: 05983660000153
# computing metrics for: 06006188000161
# computing metrics for: 06015361000198
# computing metrics for: 06015368000100
# computing metrics for: 06015421000172
# computing metrics for: 06028596000114
# computing metrics for: 06032801000115
# computing metrics for: 06035405000141
# computing metrics for: 06037357000120
# saving file...
# computing metrics for: 06041290000106
# computing metrics for: 06051151000155
# computing metrics for: 06066725000169
# computing metrics for: 06066907000130
# computing metrics for: 06069957000170
# computing metrics for: 06070574000112
# computing metrics for: 06077427000174
# computing metrics for: 06077638000107
# computing metrics for: 06078264000144
# computing metrics for: 06079087000110
# computing metrics for: 06081490000184
# computing metrics for: 06084858000168
# computing metrics for: 06084861000181
# computing metrics for: 06086398000107
# computing metrics for: 06086410000183
# computing metrics for: 06092123000186
# computing metrics for: 06095361000145
# computing metrics for: 06095367000112
# computing metrics for: 06095369000101
# computing metrics for: 06095406000181
# computing metrics for: 06095411000194
# saving file...
# computing metrics for: 06095416000117
# computing metrics for: 06095438000187
# computing metrics for: 06095452000180
# computing metrics for: 06102093000141
# computing metrics for: 06118222000190
# computing metrics for: 06124241000129
# computing metrics for: 06124248000140
# computing metrics for: 06124253000153
# computing metrics for: 06124254000106
# computing metrics for: 06126884000101
# computing metrics for: 06127871000157
# computing metrics for: 06128183000101
# computing metrics for: 06134949000160
# computing metrics for: 06137840000187
# computing metrics for: 06170624000133
# computing metrics for: 06170653000103
# computing metrics for: 06170687000190
# computing metrics for: 06175652000143
# computing metrics for: 06175696000173
# computing metrics for: 06180170000181
# computing metrics for: 06185715000142
# saving file...
# computing metrics for: 06190196000100
# computing metrics for: 06190263000197
# computing metrics for: 06190338000130
# computing metrics for: 06215101000166
# computing metrics for: 06224719000192
# computing metrics for: 06234238000168
# computing metrics for: 06234268000174
# computing metrics for: 06234360000134
# computing metrics for: 06235449000115
# computing metrics for: 06241214000136
# computing metrics for: 06245549000122
# computing metrics for: 06251554000148
# computing metrics for: 06258544000134
# computing metrics for: 06275894000109
# computing metrics for: 06279728000180
# computing metrics for: 06279743000129
# computing metrics for: 06279843000155
# computing metrics for: 06288668000162
# computing metrics for: 06290634000102
# computing metrics for: 06290652000194
# computing metrics for: 06301947000119
# saving file...
# computing metrics for: 06331780000139
# computing metrics for: 06342396000131
# computing metrics for: 06342412000196
# computing metrics for: 06349816000101
# computing metrics for: 06375333000181
# computing metrics for: 06865916000190
# computing metrics for: 06866051000187
# computing metrics for: 06866860000199
# computing metrics for: 06866874000102
# computing metrics for: 06867811000170
# computing metrics for: 06867846000100
# computing metrics for: 06867854000156
# computing metrics for: 06871308000199
# computing metrics for: 06871833000104
# computing metrics for: 06877816000184
# computing metrics for: 06877846000190
# computing metrics for: 06877860000194
# computing metrics for: 06885683000198
# computing metrics for: 06888302000124
# computing metrics for: 06893041000130
# computing metrics for: 06916384000173
# saving file...
# computing metrics for: 06916397000142
# computing metrics for: 06918966000199
# computing metrics for: 06929716000154
# computing metrics for: 06929785000168
# computing metrics for: 06935532000105
# computing metrics for: 06940782000125
# computing metrics for: 06953275000126
# computing metrics for: 06959024000159
# computing metrics for: 06964937000163
# computing metrics for: 06964949000198
# computing metrics for: 06969451000118
# computing metrics for: 06970146000146
# computing metrics for: 06970336000163
# computing metrics for: 06985322000113
# computing metrics for: 06988623000109
# computing metrics for: 07005590000194
# computing metrics for: 07013315000112
# computing metrics for: 07018136000178
# computing metrics for: 07019857000100
# computing metrics for: 07046169000121
# computing metrics for: 07047842000148
# saving file...
# computing metrics for: 07048624000128
# computing metrics for: 07048645000143
# computing metrics for: 07050742000170
# computing metrics for: 07050946000101
# computing metrics for: 07058057000190
# computing metrics for: 07077991000150
# computing metrics for: 07082784000193
# computing metrics for: 07088369000147
# computing metrics for: 07089263000168
# computing metrics for: 07094389000120
# computing metrics for: 07096326000103
# computing metrics for: 07096435000120
# computing metrics for: 07096468000170
# computing metrics for: 07096479000150
# computing metrics for: 07096486000152
# computing metrics for: 07096546000137
# computing metrics for: 07098272000115
# computing metrics for: 07098295000120
# computing metrics for: 07098323000109
# computing metrics for: 07098360000117
# computing metrics for: 07103364000146
# saving file...
# ...
# computing metrics for: 31660348000139
# computing metrics for: 31660364000121
# computing metrics for: 31660388000180
# computing metrics for: 31666614000130
# computing metrics for: 31666877000140
# computing metrics for: 31713958000153
# computing metrics for: 31820717000103
# computing metrics for: 31820758000108
# computing metrics for: 31820799000196
# computing metrics for: 31820901000153
# computing metrics for: 31820924000168
# computing metrics for: 31820936000192
# computing metrics for: 31844783000113
# computing metrics for: 31846425000140
# computing metrics for: 31848144000126
# computing metrics for: 31848248000130
# computing metrics for: 31874833000105
# computing metrics for: 31905106000168
# computing metrics for: 31908013000197
# saving file...
# computing metrics for: 31908030000124
# computing metrics for: 31908037000146
# computing metrics for: 31922843000179
# computing metrics for: 31923761000149
# computing metrics for: 31923988000194
# computing metrics for: 31932672000169
# computing metrics for: 31932715000106
# computing metrics for: 31933186000165
# computing metrics for: 31933729000144
# computing metrics for: 31933918000117
# computing metrics for: 31933992000133
# computing metrics for: 31934014000106
# computing metrics for: 31934038000165
# computing metrics for: 31936732000111
# computing metrics for: 31936857000141
# computing metrics for: 31937303000169
# computing metrics for: 31937476000187
# computing metrics for: 31938472000113
# computing metrics for: 31944006000140
# computing metrics for: 31951995000108
# computing metrics for: 31961612000174
# saving file...
# computing metrics for: 31961936000102
# computing metrics for: 31962028000133
# computing metrics for: 31962100000122
# computing metrics for: 31963220000144
# computing metrics for: 31963249000126
# computing metrics for: 31963315000168
# computing metrics for: 31963396000104
# computing metrics for: 31963459000114
# computing metrics for: 31963539000170
# computing metrics for: 31963591000126
# computing metrics for: 31963604000167
# computing metrics for: 31964047000107
# computing metrics for: 31964074000171
# computing metrics for: 31964132000167
# computing metrics for: 31964159000150
# computing metrics for: 31964408000107
# computing metrics for: 31964457000140
# computing metrics for: 31964487000156
# computing metrics for: 31964541000163
# computing metrics for: 31964900000182
# computing metrics for: 31964961000140
# saving file...
# computing metrics for: 31972790000109
# computing metrics for: 31975598000168
# computing metrics for: 31981829000146
# computing metrics for: 31981852000130
# computing metrics for: 32033283000164
# computing metrics for: 32041557000167
# computing metrics for: 32041623000107
# computing metrics for: 32041670000142
# computing metrics for: 32041825000140
# computing metrics for: 32041875000128
# computing metrics for: 32042243000189
# computing metrics for: 32045208000113
# computing metrics for: 32064571000186
# computing metrics for: 32064707000158
# computing metrics for: 32068007000131
# computing metrics for: 32071783000190
# computing metrics for: 32072964000131
# computing metrics for: 32073525000143
# computing metrics for: 32074840000195
# computing metrics for: 32075119000110
# computing metrics for: 32075364000127
# saving file...
# computing metrics for: 32075594000196
# computing metrics for: 32088041000178
# computing metrics for: 32101886000156
# computing metrics for: 32102131000176
# computing metrics for: 32102192000133
# computing metrics for: 32102289000146
# computing metrics for: 32138351000150
# computing metrics for: 32138635000146
# computing metrics for: 32138793000104
# computing metrics for: 32138958000130
# computing metrics for: 32139747000111
# computing metrics for: 32139841000170
# computing metrics for: 32140660000164
# computing metrics for: 32158371000192
# computing metrics for: 32158382000172
# computing metrics for: 32158393000152
# computing metrics for: 32158410000151
# computing metrics for: 32158424000175
# computing metrics for: 32158430000122
# computing metrics for: 32158441000102
# computing metrics for: 32158567000187
# saving file...
# computing metrics for: 32158590000171
# computing metrics for: 32158609000180
# computing metrics for: 32158806000107
# computing metrics for: 32158821000147
# computing metrics for: 32158830000138
# computing metrics for: 32161826000129
# computing metrics for: 32162706000146
# computing metrics for: 32162733000119
# computing metrics for: 32163162000137
# computing metrics for: 32179530000135
# computing metrics for: 32196648000171
# computing metrics for: 32203189000106
# computing metrics for: 32203262000140
# computing metrics for: 32203308000120
# computing metrics for: 32222722000187
# computing metrics for: 32222863000108
# computing metrics for: 32222875000124
# computing metrics for: 32222977000140
# computing metrics for: 32223688000165
# computing metrics for: 32223816000170
# computing metrics for: 32225253000150
# saving file...
# computing metrics for: 32225478000106
# computing metrics for: 32225606000111
# computing metrics for: 32225663000109
# computing metrics for: 32227093000188
# computing metrics for: 32227268000157
# computing metrics for: 32227355000104
# computing metrics for: 32228473000137
# computing metrics for: 32229782000121
# computing metrics for: 32236825000104
# computing metrics for: 32236875000183
# computing metrics for: 32236915000197
# computing metrics for: 32238299000103
# computing metrics for: 32238591000126
# computing metrics for: 32239267000122
# computing metrics for: 32239328000151
# computing metrics for: 32239565000112
# computing metrics for: 32239786000190
# computing metrics for: 32240069000189
# computing metrics for: 32240183000109
# computing metrics for: 32240211000198
# computing metrics for: 32240439000188
# saving file...
# computing metrics for: 32240456000115
# computing metrics for: 32240508000153
# computing metrics for: 32240522000157
# computing metrics for: 32245930000100
# computing metrics for: 32245947000159
# computing metrics for: 32246546000113
# computing metrics for: 32246789000151
# computing metrics for: 32254387000107
# computing metrics for: 32254420000190
# computing metrics for: 32265518000143
# computing metrics for: 32265527000134
# computing metrics for: 32265550000129
# computing metrics for: 32273402000156
# computing metrics for: 32273477000137
# computing metrics for: 32273485000183
# computing metrics for: 32273489000161
# computing metrics for: 32273491000130
# computing metrics for: 32273503000127
# computing metrics for: 32273507000105
# computing metrics for: 32273514000107
# computing metrics for: 32273523000106
# saving file...
# computing metrics for: 32273528000120
# computing metrics for: 32273536000177
# computing metrics for: 32273540000135
# computing metrics for: 32273549000146
# computing metrics for: 32273554000159
# computing metrics for: 32274211000109
# computing metrics for: 32291847000169
# computing metrics for: 32291850000182
# computing metrics for: 32291860000118
# computing metrics for: 32291869000129
# computing metrics for: 32291899000135
# computing metrics for: 32291910000167
# computing metrics for: 32291931000182
# computing metrics for: 32291936000105
# computing metrics for: 32291944000151
# computing metrics for: 32291950000109
# computing metrics for: 32291956000186
# computing metrics for: 32292504000119
# computing metrics for: 32292537000169
# computing metrics for: 32292548000149
# computing metrics for: 32292555000140
# saving file...
# computing metrics for: 32295372000189
# computing metrics for: 32295478000182
# computing metrics for: 32295526000132
# computing metrics for: 32295564000195
# computing metrics for: 32295829000155
# computing metrics for: 32295931000150
# computing metrics for: 32300293000119
# computing metrics for: 32300350000160
# computing metrics for: 32300395000134
# computing metrics for: 32308852000137
# computing metrics for: 32312051000145
# computing metrics for: 32312055000123
# computing metrics for: 32312064000114
# computing metrics for: 32312071000116
# computing metrics for: 32312081000151
# computing metrics for: 32313878000173
# computing metrics for: 32318780000109
# computing metrics for: 32318799000155
# computing metrics for: 32319373000116
# computing metrics for: 32319525000180
# computing metrics for: 32319627000104
# saving file...
# computing metrics for: 32355677000139
# computing metrics for: 32355797000136
# computing metrics for: 32356892000154
# computing metrics for: 32385211000186
# computing metrics for: 32385294000103
# computing metrics for: 32385410000194
# computing metrics for: 32386241000107
# computing metrics for: 32386581000138
# computing metrics for: 32386727000145
# computing metrics for: 32395333000153
# computing metrics for: 32395813000114
# computing metrics for: 32396191000149
# computing metrics for: 32396909000105
# computing metrics for: 32397476000102
# computing metrics for: 32397723000162
# computing metrics for: 32397847000148
# computing metrics for: 32398344000197
# computing metrics for: 32398845000173
# computing metrics for: 32398911000105
# computing metrics for: 32665773000183
# computing metrics for: 32666282000157
# saving file...
# computing metrics for: 32666326000149
# computing metrics for: 32666333000140
# computing metrics for: 32666342000131
# computing metrics for: 32666390000120
# computing metrics for: 32666428000164
# computing metrics for: 32666469000150
# computing metrics for: 32666485000143
# computing metrics for: 32668721000160
# computing metrics for: 32669088000125
# computing metrics for: 32669125000103
# computing metrics for: 32669482000163
# computing metrics for: 32704998000100
# computing metrics for: 32711748000199
# computing metrics for: 32711923000148
# computing metrics for: 32711990000162
# computing metrics for: 32712006000188
# computing metrics for: 32712027000101
# computing metrics for: 32738755000184
# computing metrics for: 32738820000171
# computing metrics for: 32739825000119
# computing metrics for: 32739928000189
# saving file...
# computing metrics for: 32740523000160
# computing metrics for: 32741500000170
# computing metrics for: 32741788000183
# computing metrics for: 32742425000162
# computing metrics for: 32742535000124
# computing metrics for: 32742747000101
# computing metrics for: 32742977000170
# computing metrics for: 32743215000199
# computing metrics for: 32743582000192
# computing metrics for: 32745056000161
# computing metrics for: 32745260000182
# computing metrics for: 32745426000160
# computing metrics for: 32745504000127
# computing metrics for: 32745560000161
# computing metrics for: 32745593000101
# computing metrics for: 32745642000106
# computing metrics for: 32753864000170
# computing metrics for: 32754920000191
# computing metrics for: 32754982000101
# computing metrics for: 32756019000159
# computing metrics for: 32756812000158
# saving file...
# computing metrics for: 32757330000112
# computing metrics for: 32760026000124
# computing metrics for: 32760103000146
# computing metrics for: 32760110000148
# computing metrics for: 32760138000185
# computing metrics for: 32761589000137
# computing metrics for: 32771148000116
# computing metrics for: 32771215000100
# computing metrics for: 32773105000170
# computing metrics for: 32773560000175
# computing metrics for: 32773622000149
# computing metrics for: 32774576000100
# computing metrics for: 32783564000134
# computing metrics for: 32784736000194
# computing metrics for: 32784859000125
# computing metrics for: 32786258000151
# computing metrics for: 32811286000181
# computing metrics for: 32811306000114
# computing metrics for: 32811397000198
# computing metrics for: 32811422000133
# computing metrics for: 32812233000185
# saving file...
# computing metrics for: 32812263000191
# computing metrics for: 32834102000107
# computing metrics for: 32834521000130
# computing metrics for: 32835495000165
# computing metrics for: 32835538000102
# computing metrics for: 32835611000146
# computing metrics for: 32841087000116
# computing metrics for: 32841189000131
# computing metrics for: 32846425000102
# computing metrics for: 32846811000102
# computing metrics for: 32846911000120
# computing metrics for: 32846986000101
# computing metrics for: 32847123000159
# computing metrics for: 32849296000106
# computing metrics for: 32889108000173
# computing metrics for: 32889197000158
# computing metrics for: 32889785000191
# computing metrics for: 32891951000194
# computing metrics for: 32893639000130
# computing metrics for: 32998646000104
# computing metrics for: 32998710000149
# saving file...
# computing metrics for: 32999355000122
# computing metrics for: 32999370000170
# computing metrics for: 32999390000141
# computing metrics for: 32999416000151
# computing metrics for: 32999453000160
# computing metrics for: 33019398000167
# computing metrics for: 33055124000123
# computing metrics for: 33055657000105
# computing metrics for: 33144370000151
# computing metrics for: 33144687000198
# computing metrics for: 33145106000132
# computing metrics for: 33146540000137
# computing metrics for: 33149272000107
# computing metrics for: 33149415000180
# computing metrics for: 33149605000106
# computing metrics for: 33150090000156
# computing metrics for: 33150361000173
# computing metrics for: 33150463000199
# computing metrics for: 33150563000115
# computing metrics for: 33150614000109
# computing metrics for: 33158131000150
# saving file...
# computing metrics for: 33193185000157
# computing metrics for: 33269287000109
# computing metrics for: 33269355000130
# computing metrics for: 33270063000117
# computing metrics for: 33346541000125
# computing metrics for: 33420271000155
# computing metrics for: 33490022000136
# computing metrics for: 33755721000160
# computing metrics for: 33898268000141
# computing metrics for: 33898293000125
# computing metrics for: 34108933000119
# computing metrics for: 34123589000137
# computing metrics for: 34231794000116
# computing metrics for: 34231810000170
# computing metrics for: 34231820000106
# computing metrics for: 34246353000198
# computing metrics for: 34246364000178
# computing metrics for: 34246372000114
# computing metrics for: 34246376000100
# computing metrics for: 34246380000160
# computing metrics for: 34246384000149
# saving file...
# computing metrics for: 34246519000176
# computing metrics for: 34258142000175
# computing metrics for: 34432116000111
# computing metrics for: 34462142000192
# computing metrics for: 34475068000149
# computing metrics for: 34582493000137
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 6
#       4 count=0
#       5 for cnpj in funds_series['CNPJ_FUNDO'].unique():
# ----> 6     serie = funds_series[funds_series['CNPJ_FUNDO'] == cnpj]
#       8     if len(serie) > serie_size:
#       9         print(f'computing metrics for: {cnpj}')
#
# File c:\Users\crist\.conda\envs\data-analysis\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File c:\Users\crist\.conda\envs\data-analysis\lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File c:\Users\crist\.conda\envs\data-analysis\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\crist\.conda\envs\data-analysis\lib\site-packages\pandas\core\ops\array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Users\crist\.conda\envs\data-analysis\lib\site-packages\pandas\core\ops\array_ops.py:76, in comp_method_OBJECT_ARRAY(op, x, y)
#      74 else:
#      75     result = libops.scalar_compare(x.ravel(), y, op)
# ---> 76 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
fund_cnpj = '02838578000147'
length = 1260
serie = funds_series[funds_series['CNPJ_FUNDO'] == fund_cnpj]
metrics = tools.compute_metrics(fund_cnpj, serie,length)

metrics

# %%
fund_data['returns'] = ep.simple_returns(fund_data['value'])
fund_data['returns'].replace([np.inf, -np.inf], np.nan)
fund_data = fund_data.dropna()

selic['returns'] = ep.simple_returns(selic['value'])

selic_temp = selic[selic.index.isin(fund_data.index.values)]

# %%
data = {
    'return': (1 + fund_data['returns']).cumprod()[-1] -1, 
    'avg_return': ep.annual_return(fund_data['returns']),
    'vol': np.std(fund_data['returns']) * np.sqrt(252),
    'max_dd': ep.max_drawdown(fund_data['returns'])
}

# %%
fund_data

# %%
def sharpe_ratio(return_series, return_riskfree):
    """ Definition

    Parameters
    -------
    return_series : pandas.Series or pandas.DataFrame
        Return series.
    return_riskfree : pandas.Series or pandas.DataFrame
        Risk free asset return series.
    """
    asset_mean = np.mean(return_series)
    riskfree_mean = np.mean(return_riskfree)
    vol = np.std(return_series, ddof=1)

    return float((asset_mean - riskfree_mean) * np.sqrt(252) / vol)

# %%
sharpe_ratio(fund_data['returns'],selic_temp['returns']+1)

# %%
ep.sharpe_ratio(fund_data['returns'] )

# %%
((1 + selic_temp['returns']).cumprod()[-1] -1) * np.sqrt(252)

# %%
ep.annual_return(selic_temp['returns'])

# %%
ep.sharpe_ratio(fund_data['returns'], 0.08)

# %%
pd.DataFrame(ep.aggregate_returns(selic_temp['returns'], convert_to='yearly'))

# %%
ep.annual_return(fund_data['VL_QUOTA'], )
